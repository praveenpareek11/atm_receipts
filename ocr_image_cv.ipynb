# %%
import cv2
import sys
import pytesseract
import pandas as pd

# %%
if __name__ == '__main__':

    if len(sys.argv) < 2:
        print('Usage: python ocr_simple.py image.jpg')
        sys.exit(1)
  
  # Read image path from command line
    imPath = '/home/praveen/work/ATM_receipts/1.pdf-1_1.jpg'
    
  # Uncomment the line below to provide path to tesseract manually
    pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'

  # Define config parameters.
  # '-l eng'  for using the English language
  # '--oem 1' sets the OCR Engine Mode to LSTM only.
  #
  #  There are four OCR Engine Mode (oem) available
  #  0    Legacy engine only.
  #  1    Neural nets LSTM engine only.
  #  2    Legacy + LSTM engines.
  #  3    Default, based on what is available.
  #
  #  '--psm 3' sets the Page Segmentation Mode (psm) to auto.
  #  Other important psm modes will be discussed in a future post.  


    config = ('-l eng --oem 2 --psm 3')

  # Read image from disk
    im = cv2.imread(imPath, cv2.IMREAD_GRAYSCALE)

  # Run tesseract OCR on image
    text = pytesseract.image_to_string(im, config=config)

  # Print recognized text
    print(text)
  


 #    print("Substring 'geeks' found at index:", result)
#     a['bb']=text
#     a.to_csv('pdf.csv')
#     import json

#     with open('pdftext.txt', 'w') as f:
#         f.write(json.dumps(text))
# Out:
# IDEX India Pvt Ltd
#
# (Formerly IDEX Fluid & Metering Pvt Ltd)
# A Unit of IDEX Corporation
# Registered Office & Facotry
# Survey No 256, GIDC Manjusar,
# Savli, Near Bombardier Circle
# Dist. Vadodara - 391 775
# Gujarat, India
#
# Phone : +91 2667 662 001
#
# Fax : +91 2667 662 002
#
# Email : IDEXIndia@Ildexcorp.com
# GSTN : 24AAACL3371J1ZM
#
# CIN : U39999GJ1993PTC18768
# PAN NO- AAACL3371J
#
# LUT No. (ARN)- AD240319000411Q
# Dt. 05/03/2019
#
# STATE JURISDICTION
# GHATAK 45 (VADODARA)
#
# TAX INVOICE
# (RULE NO 7)
#
# (UNDER SECTION 31 OF GST ACT ~2047) FORMBENSIIITER
#
# ORIGINAL
# FOR RECIPIENT
#
# DUPLICATE.
#
#
#
#
#
#
# TRIPLICATE
# FOR SUPPLIFR
# Ordor No / Type Tvoice NG
# SO 19003002 19003432
#
#
#
#
#
#
# Tnvoice Date,
#
# 27/09/19
#
# Page
#
# 10f1
#
# Customer Purchase Order No
#
# 4500016500 dt 21.09.2019
#
# Payment Terms.
#
# 90 days PDC
#
# TR Number / UT-1 Number
#
# YATAYAT LR 033-27160
# FRGHT AND INSU BY CUSTOMR
# Carrier and Mode of Trans
#
# Transport by road
# Freight Terms [ INCOTERMS
# EXW, ex works, pickup
#
#
#
#
#
#
#
# e
#
#
#
# SOLD TO
#
# SHIP TO
#
#
#
# GJ Gujarat
#
# AGS TRANSACT TECHNOLOGIES LTD DAMAN
# SURVEY NO 1723 173 2 PART A
#
# GROUND FLOOR ATIYAWAD
#
# DHABHEL
#
# DAMAN
# 396210  INDIA
# GSTIN 25AAECA0901H1ZA
#
#
#
# Product Number
#
# Line
#
# No. Description
# 1.00 6709()0002
# Xsmart AGS Model
# IGST 18.00C0
# Invoice Total:
#
# Invoice TAX Total:
#
#
#
# GJ Gujarat
#
# AGS TRANSACT TECHNOLOGIES LTD DAMAN
# SURVEY NO 172 3 173 2 PART A
# GROUND FLOOR ATIYAWAD
#
# DHABHEL
# |DAMAN
# 396210  INDIA
#
# GSTIN 25AAECA0901H1ZA
#
# Qty
# HSN/SAC  Shipped
# 847982 40.00000 EA
#
# G RN No-_\E_Z—A‘
# 2%|91Y9 RIS
#
# Unit Price
# (INR)
#
# Total Price
# (INR)
#
#
#
# 73,097.00 2,923,880.00
#
# 13,157.4600 526,298 40
#
# Total Invoice amount in words: Rupees THIRTY FOUR LAC EIFTY THOUSAND ONE HUNDRED SEVENTY EIGHT AND
# AISE FORTY ONLY
# ?otaﬁ%ax mgunl mwords: Rupees FIVE LAC TWENTY SIX THOUSAND TWO HUNDRED NINETY EIGHT AND PAISE
#
# FORTY ONLY
#
# Bank Dotal
# Bank Name
# Bank Account Number :- 134209642001
# Bank IFSC Code :- HSBC0380002
# Declaration:
#
# We declare
#
#
#
#
#
# Yo us either directly or indirectly in any manner other than the amounts indicated here
#
# These products and related technical information, data, documents and materials may
#
# regulations and/or US trade embargo reguiations
#
# 1n3he case of dual-use items and technology subject to European Union Regulation (. C)
# exporied from the EU, and. if certain dual-use items and technology identified in the Regul
# n case of products and technology exported from the US: These commodities, technolagy of
# Diversion contrary to US law is prohibited
#
# accordance with US Export Administration Regulations.
#
# R/751809 XJDEQ0DT - 2032115
#
# 229%
#
# 219|201
#
#
#
# .- THE HONGKONG AND SHANGHAT BANKING CORPORATION LTD.
#
# M. ne best of our knowledge and belief that the particulars stated herein are true and correct and there is no additional consideration
# be subject to export controls under EU and/or US export
# No. 428/2009: An export license may be requied if
#
# ation. if exported to another EU member state.,
# software were exported from the United States in
#
# For IDEX India Pvt. Ltd
#
# VIRAL
# GOVINDB
# HAI SHAH

# %%
pd.read_csv
