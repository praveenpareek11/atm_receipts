# %%
from PIL import Image
from pytesseract import *

print(image_to_string(Image.open('atm_1.png')))
print(image_to_string(Image.open('atm_2.png'), lang='eng'))
# Out:
# (27/295
#
#
#
# CASSETTE
# REJECTED
# REMALNING
# Di SPENSED
# TOTAL
#
#
#
#
#
#
#
#
#
#
# CASSETTE
#
#
#
#
#
#
#
# LAST CLEARED
#
# (P1CIGI Bank
#
#
#
#
#
#
# khayaal aapka
#
#
#
#
# 16: 05NL
#
# tS PE 2
#
#
#
#
#
# TYPE 1
#
# 0001493 0000477
#
#
#
#
#
# OOU0LOL
# OU00578
#
# DOQ0040 ©
# 0001533
#
# 6000335 0000630
# 0001868 0001208
#
# TTee 3 TYPE qd
#
# 4000590 oQ000000
# JIIGO1L61 ~—§$000000
# GOGO751 GOOG0G0G
# OO00974 OOUGGOO
# QOO0L 725 5000000
#
# ' O9/26/19 14: 58Nn1.
# A}
#
#
#
# V/ fi
#
# iW ALL UN TEs RS
#
# } KANSACT ON ( OUN |
# (0000429.
#
# CASH DY SPE NSER
#
# GOU37 4 hota] Diverted
#
# JO000 lotal IND) ane
# Cassette CRIN) =
#
# (23 Dispensed-y Bric
#
# J014 | Rema ining Notes
# JOO]? Dive; rted Notes
# Cas. te} 2 (BIND) /
#
# GOO00 Pi Spenceg Notes
#
# 00000 Remaining Notes
#
# JOGO Divertead Notes
# Cassette 3 (BIN3) SE
#
# BOO72 Dee spensed Notes
# 01977 Sone toh Notes
#
# fell igaye no, PURE a
# Or
#
# 10709
# 00325
#
#
#
#
#
#
#
#
#
#
#
# ee Estey ENS
#
# Dy« Pensagd Notes
# Remaining Notes
#
# Le
# Rj le
#
#
#
#
#
#
#
#
# cunrent data id ce
# 09/27 414 lds Ags!
